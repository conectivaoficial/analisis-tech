# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url ='https://datosabiertos.jcyl.es/web/jcyl/risp/es/medio-ambiente/calidad_aire_historico/1284212629698.csv'
df=pd.read_csv(url, sep=';')
df.head()
# Out:
#         Fecha  CO (mg/m3)  NO (ug/m3)  NO2 (ug/m3)  O3 (ug/m3)  PM10 (ug/m3)  \
# 0  2020-12-31         0.6         8.0         16.0         NaN           6.0
# 1  2020-12-31         NaN         2.0          6.0         NaN           8.0
# 2  2020-12-31         NaN         8.0          2.0        65.0           4.0
# 3  2020-12-31         NaN         1.0          4.0        58.0          21.0
# 4  2020-12-31         NaN         1.0          1.0         NaN           6.0
#
#    PM25 (ug/m3)  SO2 (ug/m3) Provincia                     Estación  \
# 0           NaN          1.0    Burgos                      Burgos1
# 1           NaN          4.0      León            C.T.L.R. - Naredo
# 2           NaN          2.0      León                  Carracedelo
# 3           NaN         17.0      León                     La Robla
# 4           NaN          2.0      León  Tudela Veguin-Tudela Veguin
#
#      Latitud  Longitud                      Posición
# ...
