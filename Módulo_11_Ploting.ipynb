# %% [markdown]
# <p><img alt="Colaboratory logo" height="140px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px"></p>
#
# # **Machine Learning-Sapiencia**
#
# ## **Sesión 11**
#
# ## **Contenido**
#
# - <a href="#mat"> Matplotlib</a><br>
#   - <a href="#fig"> Creando figuras y ejes</a><br>
#   - <a href="#per"> Personalización básica del gráfico</a><br>
#   - <a href="#sty"> Cambiando el estilo de graficación</a><br>
#   - <a href="#mul"> Creando mútiples gráficos</a><br>
# - <a href="#sea"> Seaborn</a><br>
# - <a href="#sci"> Scipy</a><br>

# %% [markdown]
# <p><a name="mat"></a></p>
#
# # **Matplotlib**
#
# Matplotlib es una herramienta para visualización de datos en Python, construida sobre arreglos de NumPy.
#
# Para todas las visualizaciones con Matplotlib, comenzamos creando una figura y un eje o conjunto de ejes. Una visualización típica es de la siguiente forma:

# %% [markdown]
# <p><img alt="Colaboratory logo" height="300px" src="https://i.imgur.com/CN4dd50.jpg" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# En esta imagen vemos cómo hemos generado 4 sencillas gráficas dispuestas en una matriz de 2x2. El primero de los conceptos a tratar es el de figura (figure). Ésta es el espacio que abarca las cuatro gráficas y que, en este ejemplo, se muestra de color verdoso con un borde verde un poco más fuerte. Es decir, en la imagen anterior, la figura sería la siguiente:

# %% [markdown]
# <p><img alt="Colaboratory logo" height="200px" src="https://i.imgur.com/LzKT7CG.jpg" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Dentro de la figura nos encontramos con las cuatro mencionadas gráficas, cada una de las cuales se ha creado sobre un *conjunto de ejes* (axes). Se muestran a continuación los cuatro conjuntos de ejes:

# %% [markdown]
# <p><img alt="Colaboratory logo" height="300px" src="https://i.imgur.com/9WmCGDP.jpg" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Vemos que del concepto "ejes" representa características como el título de la gráfica, las marcas en los ejes (lo que en matplotlib se denominan ticks), etc.
#
# Por último, dentro de cada conjunto de ejes encontramos lo llamamos gráfica (plot). Estas serían las cuatro gráficas generadas:

# %% [markdown]
# <p><img alt="Colaboratory logo" height="300px" src="https://i.imgur.com/kfaMZLp.jpg" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# En resumen, la *figura* puede considerarse como un contenedor único que contiene todos los objetos que representan los ejes, gráficos y etiquetas. Por otra parte, el *conjunto de ejes* es un cuadro delimitador con marcas y etiquetas, que eventualmente contendrá los elementos del gráfico que componen nuestra visualización.

# %% [markdown]
# <p><a name="fig"></a></p>
#
# #  **Creando figuras y ejes**
#
# Usaremos el submódulo `pyplot` de la librería para realizar nuestros gráficos:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# Existen dos formas en que podemos crear figuras y ejes. La forma más simple se conoce como *interfaz tipo Matlab*, donde la figura y los ejes se crean automáticamente: cuando utilizamos la función `plt.plot` se generan una figura y un conjunto de ejes de forma implícita

# %%
a = 5
print(5)
# Out:
# 5

# %%
x = np.linspace(-2*np.pi,2*np.pi,100)

plt.plot(x,np.sin(x))

plt.show()

# %% [markdown]
# La segunda forma utiliza un estilo de programación orientado a objetos: referenciamos la figura y los ejes mediante las variables `fig` y `ax` respectivamente, y serán métodos y atributos de estas variables los que nos permitan personalizar la visualización.
#
# Una primera opción para crear la figura y los ejes es utilizar las funciones `plt.figure` y `plt.axes`, que nos devuelven una referencia de la figura y conjunto de ejes utilizados.

# %%
# se crean la figura y los ejes
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# Una vez tenemos la referencia al conjunto de ejes `ax` podemos crear una gráfica ejecutando el método `plot` sobre `ax`:

# %%
# se crean la figura y los ejes
fig = plt.figure()
ax = plt.axes()

y = np.sin(x)
# se realiza la grafica mediante la referencia al eje
ax.plot(x,y);

# %% [markdown]
# Podemos utilizar alternativamente la función `subplots` para crear la figura y el conjunto de ejes:

# %%
# se crean la figura y los ejes
fig, ax = plt.subplots()
# se realiza la grafica mediante la referencia al eje
ax.plot(x,y)
plt.show()

# %% [markdown]
# <p><a name="per"></a></p>
#
# # **Personalización básica del gráfico**
#
# * **Estilo MATLAB**
#
# La función `plt.plot` realiza por defecto un gráfico de línea. Podemos personalizar el color, el estilo y el marcador de la línea mediante los argumentos por palabra clave `color`, `linestyle` y `marker`, respectivamente. E

# %%
plt.plot(x,y,color = 'blue', linestyle= '-.', marker = 'o')
plt.show()

# %% [markdown]
# En el caso del color, podemos pasar este de forma completa o abreviada:
#
# >
#     COM       ABR
#     blue ---- b
#     green --- g
#     red ----- r
#     cyan ---- c
#     magenta - m
#     yellow -- y
#     black --- k
#     white --- w
#
# De forma similar, podemos pasar el estilo de la línea de forma completa o abreviada:
# >
#     COM        ABR      DESCRIPCIÓN
#     solid ---- "-" ---- línea sólida
#     dashed --- "--" --- línea discontinua
#     dashdot -- "-." --- línea discontinua+punto
#     dotted --- ":" ---- línea punteada
#
# Y finalmente, para el marcador, algunas opciones son:
# >
#
#     "o" ------ círculo
#     "^" ------ triángulo
#     "p" ------ pentágono
#     "h" ------ hexágono
#     "s" ------ cuadrado
#     "|" ------ línea vertical
#     "_" ------ línea horizontal
#     "+" ------ más
#     "x" ------ equis

# %% [markdown]
# Podemos reducir estos tres argumentos a un solo `string` donde se indique (sin importar el orden) los tres caracteres correspondientes a los argumentos. Por ejemplo, con el string `"go:"`, se generará una línea de color verde, discontinua y con marcadores circulares:

# %%
plt.plot(x,y,'gs-.')
plt.show()

# %% [markdown]
# Podemos agregar al gráfico un título y etiquetas para los ejes $x$ y $y$, con los métodos `plt.title`, `plt.xlabel` y `plt.xylabel`, respectivamente:

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.')


# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

plt.show()

# %% [markdown]
# Ahora, para definir los límites de los ejes tenemos dos opciones. La primera es utilizando los métodos `plt.xlim` y `plt.ylim`. Alternativamente, el método `plt.axis`, con el cual podemos especificar los límites de los ejes pasando una lista que contiene como elementos los límites de la siguiente manera:
# >
#     plt.axis([xmin, xmax, ymin, ymax])

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.')


# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

#límites
plt.axis([-2*np.pi-0.5,2*np.pi+0.5,-1-0.5,1+0.5])

plt.show()

# %% [markdown]
# Con las palabras clave `tight` y `equal`, podemos definir los ejes de manera "ajustada" en el primer caso, y ejes iguales en el segundo caso:

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.')


# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

#límites
plt.axis('tight')

plt.show()

# %% [markdown]
# Para agregar una leyenda de la función, podemos pasar una lista con la(s) leyenda(s) a la función `plt.legend`, o utilizando el argumento por palabra clave ``label`` dentro de la función ``plt.plot()``

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.', label = '$sin(x)$')


# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

#límites
plt.axis([-2*np.pi-0.5,2*np.pi+0.5,-1-0.5,1+0.5])
plt.legend()
plt.show()

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.')
z=np.cos(x)
plt.plot(x,z,'r*--')

# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

#límites
plt.axis('tight')
plt.legend(['$\sin(x)$','$\cos(x)$'])
plt.savefig('Figura_trigonometrica')
plt.show()

# %%
#Conectar notebook con mi drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-14-7ebcec9f74d4> in <module>()
#       1 #Conectar notebook con mi drive
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# Nótese que debemos incluir ``plt.legend()`` para que se genere la leyenda. Además, podemos mostrar el título, los ejes y la leyenda, en un formato matemático encerrando la expresión entre los símbolos peso `"$"`
#
# Podemos además especificar, mediante el argumento por palabra clave `loc`, la posición de la leyenda dentro del gráfico. Por defecto, se utiliza la "mejor" posición (best). Las opciones disponibles son:
# >
#     POSICIÓN        DESCRIPCIÓN
#     best ---------- mejor
#     upper right --- sup der
#     upper left ---- sup izq
#     lower left ---- inf izq
#     lower right --- inf der
#     right --------- der
#     center left --- centro izq
#     center right -- cento der
#     lower center -- inf central
#     upper center -- sup central
#     center -------- central

# %%
# interfaz MATLAB
plt.plot(x,y,'gs-.', label = '$\sin(x)$' )


# etiquetas de los ejes
plt.xlabel('$x$')
plt.ylabel('$\sin(x)$')

# titulo
plt.title('Función Seno')

#límites
plt.axis('tight')
plt.legend(loc='upper right')
plt.savefig('Figura_trigonometrica')
plt.show()

# %% [markdown]
# * **Estilo orientado a objetos**
#
# Si bien la mayoría de las funciones en `plt` se traducen directamente a métodos `ax` (como `plt.plot()` → `ax.plot()`, `plt.legend()` → `ax.legend()`, etc.), este no es el caso para todos los comandos. En particular, las funciones para establecer límites, etiquetas y títulos se modifican ligeramente. Para realizar la transición entre las funciones de estilo MATLAB y los métodos orientados a objetos, realizamos los siguientes cambios (Puede consultar todos los atributos y métodos de la clase `axes` en este [link](https://matplotlib.org/3.1.1/api/axes_api.html#array)):
#
# * `plt.plot()`   → `ax.plot()`
# * `plt.legend()` → `ax.legend()`
# * `plt.axis()`   → `ax.axis()`
#
# * `plt.xlabel()` → `ax.set_xlabel()`
# * `plt.ylabel()` → `ax.set_ylabel()`
# * `plt.xlim()`   → `ax.set_xlim()`
# * `plt.ylim()`   → `ax.set_ylim()`
# * `plt.title()`  → `ax.set_title()`

# %% [markdown]
# Realicemos la misma gráfica anterior en el estilo orientado a objetos:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'g*:', label = '$sin(x)$')


# etiquetas de los ejes
ax.set_xlabel('$x$')
ax.set_ylabel('$\sin(x)$')

# titulo
ax.set_title('Función Seno')

#límites
ax.axis('tight')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# En el estilo orientado a objetos, en lugar de llamar estas funciones individualmente, es más conveniente usar el método `ax.set()` para establecer todas estas propiedades a la vez:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'g*:', label = '$sin(x)$')


# configura ejes y título
ax.set(xlabel = '$x$',
       ylabel = '$\sin(x)$',
       title = 'Función Seno')

#ax.set_xlabel('$x$')
#ax.set_ylabel('$\sin(x)$')

#ax.set_title('Función Seno')

#límites
ax.axis('tight')
ax.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# <p><a name="sty"></a></p>
#
# # **Cambiando el estilo de graficación**
#
# Ya vimos el estilo de graficación estándar que se tiene en `matplotlib.pyplot`.
#
# Una personalización del fondo (y otras características del gráfico) requiere la especificación de la figura. Sin embargo, podemos utilizar la directiva `plt.style` para elegir diferentes estilos para nuestras figuras.
#
# Mediante el atributo `plt.style.available` podemos acceder a los diferentes estilos disponibles:

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Podemos elegir alguno de estos estilos utilizando el método `plt.style.use`:

# %%
# elegimos el estilo seaborn
#plt.style.use('classic')
plt.style.use('seaborn')

fig, ax = plt.subplots()

ax.plot(x, y, 'g*:', label = '$sin(x)$')


# configura ejes y título
ax.set(xlabel = '$x$',
       ylabel = '$\sin(x)$',
       title = 'Función Seno')


#límites
ax.axis('tight')
ax.legend(loc = 'upper right')
ax.grid(True)
plt.show()

# %% [markdown]
# <p><a name="mul"></a></p>
#
# # **Creando mútiples gráficos**
#
# Para la generación de la figura y de uno o más conjuntos de ejes podemos recurrir a la función `plt.subplots`, la cual crea estos objetos y devuelve una referencia a la figura y al conjunto de ejes (si solo se ha creado uno) o a una lista de referencias a los conjuntos de ejes (si se han creado dos o más).
#
# Como ya vimos, la función `plt.subplots` crea por defecto una figura y un solo eje. Para tener dos gráficos en el mismo eje utilizamos la función `ax.plot` reiteradamente:

# %%
# elegimos el estilo seaborn
#plt.style.use('classic')

fig, ax = plt.subplots(figsize = (10,6))

ax.plot(x, y, 'g*:', label = '$\sin(x)$')
ax.plot(x, np.cos(x),'bo--', label = '$\cos(x)$')


# configura ejes y título
ax.set(xlabel = '$x$',
       ylabel = '$y(x)$',
       title = 'Funciones trigonométricas')


#límites
ax.axis('tight')
ax.legend()
ax.grid(True)
plt.show()

# %% [markdown]
# Si queremos especificar el número de ejes a usar, debemos hacerlo explícitamente en la función `plt.subplots`. Sus dos primeros argumentos representan el número de filas y columnas a utilizar, solo que en este caso la referencia a las figuras se hace mediante `ax`:

# %%
fig, ax = plt.subplots( 2,2)
print(f' tipo de ax: {type(ax)}')
# Out:
#  tipo de ax: <class 'numpy.ndarray'>

# %% [markdown]
# Note que `ax` es un arreglo de NumPy, en este caso de forma `(2,2)`, donde cada una de las entradas contiene un conjunto de ejes. Para pintar una gráfica en alguno de estos conjuntos de ejer simplemente debemos referenciar el eje mediante el elemento de `ax` correspondiente:

# %%
fig, ax = plt.subplots( 2,2)

ax[0,0].plot(x,y)
ax[0,1].plot(x,np.cos(x))
ax[1,0].plot(x,np.tan(x))
ax[1,1].plot(x,np.arctan(x))

ax[0,0].set(title = 'seno', xlabel = '$x$', ylabel = 'y')
ax[0,1].set(title = 'cos', xlabel = '$x$', ylabel = 'y')
ax[1,0].set(title = 'tan', xlabel = '$x$', ylabel = 'y')
ax[1,1].set(title = 'cotan', xlabel = '$x$', ylabel = 'y')
plt.show()

# %% [markdown]
# Note que en este caso los ejes de las funciones `tan` y `atan` se están solapando con la etiqueta del eje $x$ del primer y segundo eje respectivamente. Para tener cada atributo de la figura en su lugar, podemos utilizar el argumento por palabra clave `constrained_layout` en la función `plt.subplots`:

# %%
fig, ax = plt.subplots( 2,2, constrained_layout= True)

ax[0,0].plot(x,y)
ax[0,1].plot(x,np.cos(x))
ax[1,0].plot(x,np.tan(x))
ax[1,1].plot(x,np.arctan(x))

ax[0,0].set(title = 'seno', xlabel = '$x$', ylabel = 'y')
ax[0,1].set(title = 'cos', xlabel = '$x$', ylabel = 'y')
ax[1,0].set(title = 'tan', xlabel = '$x$', ylabel = 'y')
ax[1,1].set(title = 'cotan', xlabel = '$x$', ylabel = 'y')
plt.show()

# %% [markdown]
# Otros argumentos por palabra clave útiles de la función `plt.subplots`, son `sharex` y `sharey`, que nos permiten compartir los ejes $x$ y $y$, respectivamente, entre las diferentes gráficas.
#
# recuerde consultar la documentación de la función `plt.subplots` para obtener más información respecto a los argumentos disponibles de la función.
#
# Finalmente, podemos añadir un título a la figura con el método `suptitle` del objeto `fig`:

# %%
fig, ax = plt.subplots( 2,2, constrained_layout= True, sharex= True)
fig.suptitle('Figuras trigonométricas', fontsize = 15)

ax[0,0].plot(x,y)
ax[0,1].plot(x,np.cos(x))
ax[1,0].plot(x,np.tan(x))
ax[1,1].plot(x,np.arctan(x))

ax[0,0].set(title = 'seno', xlabel = '$x$', ylabel = 'y')
ax[0,1].set(title = 'cos', xlabel = '$x$', ylabel = 'y')
ax[1,0].set(title = 'tan', xlabel = '$x$', ylabel = 'y')
ax[1,1].set(title = 'cotan', xlabel = '$x$', ylabel = 'y')
plt.show()

# %%
fig, ax = plt.subplots( 2, 2, constrained_layout= True, sharex=True, sharey= True)

ax[0,0].plot(x,y)
ax[0,1].plot(x,np.cos(x))
ax[1,0].plot(x,np.tan(x))
ax[1,1].plot(x,np.arctan(x))

ax[0,0].set(title = 'seno', xlabel = '$x$', ylabel = '$y$')
ax[0,1].set(title = 'cos', xlabel = '$x$', ylabel = '$y$')
ax[1,0].set(title = 'tan', xlabel = '$x$', ylabel = '$y$')
ax[1,1].set(title = 'cotan', xlabel = '$x$', ylabel = '$y$')
plt.show()

# %% [markdown]
# <p><a name="dis"></a></p>
#
# # **Gráficos de dispersión**
#
# Los gráficos de dispersión se utilizan para comparar los valores que toman dos variables distintas, una de las cuales se representa a lo largo del eje $x$ y la otra a lo largo del eje $y$.
#
# La gráfica resultante nos permite identificar visualmente la posible correlación entre las dos variables. Para realizar este tipo de gráficos podríamos utilizar la función `plt.plot` y remover las líneas. Sin embargo, Matplotlib ofrece una función mucho más potente `plt.scatter`. Esta función acepta como primeros dos argumentos los valores $x$ y $y$ de los puntos a mostrar. Hagamos un ejemplo sencillo: generemos valores aleatorios extraídos de una distribución normal para los valores de $x$ y de $y$:

# %%
np.random.uniform(-1,1,size=10)
# Out:
# array([-0.7991959 , -0.38554067, -0.88905043,  0.86363961, -0.26019064,
#        -0.85213933,  0.30793371,  0.23059701, -0.81566959, -0.78232971])

# %%
x = np.random.randn(40)
y = np.random.randn(40)

# %%
plt.scatter(x,y);

# %% [markdown]
# Existen casos en los que los datos se presentan en un formato que podemos acceder a variables particulares mediante una palabra clave, por ejemplo, cuando tenemos los datos almacenados en un diccionario:

# %%
dictio = {"x":np.linspace(0,50)}
dictio["y"] = dictio['x'] + 10*np.random.randn(50)
#dictio["y"] = dictio['x']

dictio
# Out:
# {'x': array([ 0.        ,  1.02040816,  2.04081633,  3.06122449,  4.08163265,
#          5.10204082,  6.12244898,  7.14285714,  8.16326531,  9.18367347,
#         10.20408163, 11.2244898 , 12.24489796, 13.26530612, 14.28571429,
#         15.30612245, 16.32653061, 17.34693878, 18.36734694, 19.3877551 ,
#         20.40816327, 21.42857143, 22.44897959, 23.46938776, 24.48979592,
#         25.51020408, 26.53061224, 27.55102041, 28.57142857, 29.59183673,
#         30.6122449 , 31.63265306, 32.65306122, 33.67346939, 34.69387755,
#         35.71428571, 36.73469388, 37.75510204, 38.7755102 , 39.79591837,
#         40.81632653, 41.83673469, 42.85714286, 43.87755102, 44.89795918,
#         45.91836735, 46.93877551, 47.95918367, 48.97959184, 50.        ]),
#  'y': array([-5.92705861,  4.42389538, 10.27867713,  8.87044088,  1.50369857,
#         -3.72751943, -4.29722002,  8.74933016, 17.5964347 , 14.6837559 ,
#          1.28469654,  9.99089085, 15.4734734 , 18.57753232, 15.7293439 ,
#         27.98994754, 19.86245669, 30.14149348, 32.71677213,  3.93978575,
#          5.41339067, 11.4686354 , 40.36380266, 24.08255524, 44.7517375 ,
#         23.15311555, 44.11240959, 45.32125371, 37.59954285, 35.74406953,
#         34.1939729 , 33.08063552, 36.32511767, 29.35776122, 39.59415664,
#         42.50511939, 32.00826598, 20.33989454, 18.85681835, 54.84117814,
#         44.92922112, 49.91559535, 43.41844802, 46.01870629, 30.81879912,
#         49.32340853, 50.28483301, 42.82867845, 35.11432661, 59.59054462])}

# %%
plt.scatter("x","y", data=dictio);

# %% [markdown]
# Este tipo de gráfica resulta más útil cuando estamos visualizando elementos de diferente clase y los mostramos en el gráfico con diferenes colores. El color de cada punto se controla mediante el argumento por palabra clave ``c``. Además, podemos cambiar el mapa de colores utilizando el argumento por palabra clave ``cmap`` y qué opaco es el color con el argumento por palabra clave ``alpha`` que va de 0 (transparente) a 1 (opaco).
#
# *Puede consultar los mapas de colores disponibles en esta [dirección](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html)*

# %%
# generemos un arreglo para separar los datos en dos clases
# y asociarlas al color
colores = (dictio['y'] < 10)*1 + (dictio['y'] >= 10)*20
colores
# Out:
# array([ 1,  1, 20,  1,  1,  1,  1,  1, 20, 20,  1,  1, 20, 20, 20, 20, 20,
#        20, 20,  1,  1, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20,
#        20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20])

# %%
plt.scatter('x', 'y', c = colores, alpha = 0.4, data = dictio, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# Podemos además modificar el tamaño de cada uno de los puntos mediante el argumento por palabra clave ``s``:

# %%
# el tamaño de los puntos aumenta a medida que x aumenta
tam = np.arange(10,60)

plt.scatter('x', 'y', c = colores, alpha = 1, s =tam , data = dictio, cmap= 'coolwarm')
plt.show()

# %%
# el tamaño de los puntos dependiendo del color

tam = (dictio['y'] < 10)*30 + (dictio['y'] >= 10)*150

plt.scatter('x', 'y', c = colores, alpha = 1, s =tam , data = dictio, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# <p><a name="sea"></a></p>
#
# # **Seaborn**

# %% [markdown]
# Existen otros múltiples tipos de gráficos como los son
#
# - Bar Graph
# - Pie Chart
# - Box Plot
# - Line Chart and Subplots
# - Heat maps
# - Histograms
#
# Entre otros, y su implementación no dista mucho de lo ya discutido. Sin embargo existen formas más sencillas de implementar muchas de estas gráficas. Con el fin de visualizarlo de una forma amigable partiremos de un ejemplo con datos de la nba

# %%
nba = pd.read_csv("https://raw.githubusercontent.com/tomasate/Datos_Clases/main/Datos_1/nba.csv", index_col="Unnamed: 0")
nba.dropna(inplace=True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %% [markdown]
# Acontinuación  responderemos las siguientes preguntas y veremos las respuestas en calidad de imagen.
# * ¿Cuáles son los cinco equipos que pagan los salarios mas altos? (sumando toda la nómina de sus jugadores).

# %%
team_salary = nba.groupby('Team', as_index=False)['Salary'].sum().sort_values(by = 'Salary', ascending = False)[:5]

#team_salary = nba.groupby('Team', as_index=False)['Salary'].sum().sort_values(by = 'Salary', ascending = False)[:5]
team_salary
# Out:
#                      Team      Salary
# 12   Los Angeles Clippers  93906914.0
# 20  Oklahoma City Thunder  81515298.0
# 9   Golden State Warriors  80535517.0
# 5     Cleveland Cavaliers  74068189.0
# 4           Chicago Bulls  73265800.0

# %%
#import seaborn as sns
sns.catplot(x ="Team", y = 'Salary', kind='bar', data = team_salary)
#Rotar las etiquetas del eje x
plt.xticks(rotation= 45);
plt.show()

# %% [markdown]
# * Separe la variable *Age* en tres grupos y cree una nueva columna llamada *Age-Group* con esta información. Muestre un gráfico de barras con el número de jugadores por grupo de edad diferenciando en esta (mediante un código de color) la posición.

# %%
#para binnear una variable continua use la función cut de pandas

nba['Age_Group'] = pd.cut(nba.Age, 3, labels=['baja', 'media', 'alta'])

#nba
sns.catplot(data = nba, x = 'Age_Group', kind='count', hue='Position');

# %% [markdown]
# * Construya dos gráficos de caja en los que se muestren los salarios vs las posiciones de los jugadores y salarios vs grupo de edad en la misma figura, de manera que compartan el eje del salario. ¿Cuál característica es más importante a la hora de definir el salario?

# %%
sns.catplot(data=nba, x= 'Position', y ='Salary', kind= 'box');

# %%
sns.catplot(data=nba, x= 'Age_Group', y ='Salary', kind= 'box');

# %%
#ambos a la vez requieren que ya no se haga con un catplot sino con el tipo de plot, específicamente con boxplot
fig, axs = plt.subplots(1,2,figsize= (10,5), sharey= True)

sns.boxplot(data=nba, x= 'Position', y ='Salary', ax= axs[0])
sns.boxplot(data=nba, x= 'Age_Group', y ='Salary', ax= axs[1]);

# %% [markdown]
# * Construya una tabla dinámica que muestre el salario promedio de los jugadores por equipo y posición para para los cinco equipos que pagan mejores salarios. Visualice este resultado mediante un mapa de calor.

# %%
# filtramos los datos para seleccionar solo los datos correspondientes a las cinco universidades que mas pagan

filtered_data = nba.loc[nba.Team.isin(team_salary.Team)]
filtered_data
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 77     Harrison Barnes  Golden State Warriors    40.0       SF  24.0    6-8
# 78        Andrew Bogut  Golden State Warriors    12.0        C  31.0    7-0
# 79           Ian Clark  Golden State Warriors    21.0       SG  25.0    6-3
# 80       Stephen Curry  Golden State Warriors    30.0       PG  28.0    6-3
# 81        Festus Ezeli  Golden State Warriors    31.0        C  26.0   6-11
# ..                 ...                    ...     ...      ...   ...    ...
# 422      Cameron Payne  Oklahoma City Thunder    22.0       PG  21.0    6-3
# 423     Andre Roberson  Oklahoma City Thunder    21.0       SG  24.0    6-7
# 424       Kyle Singler  Oklahoma City Thunder     5.0       SF  28.0    6-8
# 425       Dion Waiters  Oklahoma City Thunder     3.0       SG  24.0    6-4
# 426  Russell Westbrook  Oklahoma City Thunder     0.0       PG  27.0    6-3
#
#      Weight         College      Salary Age_Group
# 77    225.0  North Carolina   3873398.0      baja
# 78    260.0            Utah  13800000.0     media
# 79    175.0         Belmont    947276.0      baja
# 80    190.0        Davidson  11370786.0     media
# 81    265.0      Vanderbilt   2008748.0      baja
# ..      ...             ...         ...       ...
# 422   185.0    Murray State   2021520.0      baja
# 423   210.0        Colorado   1210800.0      baja
# 424   228.0            Duke   4500000.0     media
# 425   220.0        Syracuse   5138430.0      baja
# 426   200.0            UCLA  16744218.0     media
#
# [63 rows x 10 columns]

# %% [markdown]
# Una tabla dinámica en síntesis es una forma de resumir la información de manera númeríca no visual(no con gráficos ni animaciónes). Permite ver comparaciones, patrones y tendencias en ellos. En pandas es fácil hacerlas con el método `pivot_table` de los `DataFrames`

# %%
# construimos la tabla dinamica con los datos filtrados
table = filtered_data.pivot_table("Salary", index="Team", columns="Position", aggfunc='mean')
table
# Out:
# Position                          C            PF            PG            SF  \
# Team
# Chicago Bulls          1.340000e+07  3.578740e+06  1.117153e+07  1.958160e+06
# Cleveland Cavaliers    7.768435e+06  1.394101e+07  6.551592e+06  9.472760e+05
# Golden State Warriors  6.541249e+06  1.426087e+07  1.137079e+07  3.766367e+06
# Los Angeles Clippers   1.039480e+07  6.655482e+06  1.228975e+07  3.662924e+06
# Oklahoma City Thunder  6.303143e+06  2.606520e+06  9.382869e+06  8.599621e+06
#
# Position                         SG
# Team
# Chicago Bulls          5.717549e+06
# Cleveland Cavaliers    3.349079e+06
# Golden State Warriors  8.224138e+06
# Los Angeles Clippers   4.639893e+06
# Oklahoma City Thunder  3.207058e+06

# %% [markdown]
# En este caso hemos hecho una agrupación según la Posición y el equipo, aplicando la media como operación de agregación.

# %%
# generamos el mapa de calor
sns.heatmap(data = table, cmap="coolwarm",  annot= True);

# %% [markdown]
# <p><a name="sci"></a></p>
#
# # **Scipy**

# %% [markdown]
# Scipy es un completo paquete de herramientas enfocadas al desarrollo de cálculos científicos. Entre las operaciones disponibles veremos algunos ejemplos de uso de las principales:
#
# - Operaciones de entrada/salida
# - Operaciones de álgebra lineal
# - Operaciones de cálculo
# - Operaciones de optimización
# - Operaciones de procesamiento de señales
# - Operaciones de procesamiento de imagen
# - Operaciones estadísticas

# %% [markdown]
# En primer lugar, utilizaremos `scipy.io` para la importación y exportación de datos a través de ficheros `Matlab`:

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import io as spio
data = np.random.rand(3,3)
spio.savemat('data.mat', {'data': data})
data = spio.loadmat('data.mat')
#data
data['data']
# Out:
# array([[0.16299566, 0.35112319, 0.3279826 ],
#        [0.11857964, 0.74185612, 0.55637851],
#        [0.71503822, 0.52070894, 0.53011453]])

# %% [markdown]
# Utilizaremos `scipy.linalg` para operaciones de álgebra lineal. Como ejemplo, veremos su aplicación en el cálculo del determinante y la inversa de una matriz:

# %%
data = [[1, 0, 0],
       [0, 2, 0],
       [0, 0, 3]]
data
# Out:
# [[1, 0, 0], [0, 2, 0], [0, 0, 3]]

# %%
from scipy import linalg

# %%
determinante = linalg.det(data)
determinante
# Out:
# 6.0

# %%
inversa = linalg.inv(data)

# %% [markdown]
# Utilizaremos `scipy.optimize` para operaciones de optimización. Como ejemplo, veremos su aplicación en la estimación de los extremos de la función $x^2$+15 $sin(x)$:

# %%
def f(x):
    return x**2 + 15*np.sin(x)

# %%
from scipy import optimize

# %%
x = np.arange(-15, 15, 0.01)
plt.plot(x, f(x))
plt.title('$x^2+15*Sin(x)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
estimacion_minimo = optimize.minimize(f, x0=0)
estimacion_minimo
# Out:
#       fun: -12.823616887804784
#  hess_inv: array([[0.05972673]])
#       jac: array([1.1920929e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([-1.38505604])

# %%
x = np.arange(-15, 15, 0.01)
plt.plot(x, f(x))
plt.plot(estimacion_minimo.x, f(estimacion_minimo.x), 'ro')
plt.title('$x^2+15*Sin(x)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %% [markdown]
# Con `scipy.optimize` también podemos realizar operaciones de interpolación y ajuste de curvas sobre un conjunto de datos. Veámoslo con un ejemplo, mediante el ajuste de los valores mensuales de temperatura  (máxima y mínima) registrados durante 2021 en la Antártida:

# %%
maximos_temperaturas = np.array([-0.2,	-6.3,	-14, -17.4, -19,	-19.1, -21.7,	-22.8,	-20.8,	-15.5,	-6.7,	-0.8])
minimos_temperaturas = np.array([-5.5,	-11.6,	-21.1,	-24.9,	-27.1,	-27.3,	-30.1,	-31.8,	-29.4,	-23.4,	-12.7, -6])
meses = np.arange(12)
plt.plot(meses, maximos_temperaturas, 'ro')
plt.plot(meses, minimos_temperaturas, 'bo')
plt.title('Temperaturas en la Antártida - 2021')
plt.xlabel('Meses')
plt.ylabel('Máximos y Mínimos ($^\circ$C)')
plt.show()

# %%
from scipy import optimize
def temperaturas_anuales(muestras, promedio, amplitud, offset):
    return (promedio
            + amplitud * np.sin((muestras + offset) * 2 * np.pi / muestras.max()))
opt_maximos, cov_maximos = optimize.curve_fit(temperaturas_anuales, meses,
                                      maximos_temperaturas, [-50, 10, 0])
opt_minimos, cov_minimos = optimize.curve_fit(temperaturas_anuales, meses,
                                      minimos_temperaturas, [-50, 10, 0])

# %%
dias = np.linspace(0, 12, 365)
plt.plot(meses, maximos_temperaturas, 'ro')
plt.plot(dias, temperaturas_anuales(dias, *opt_maximos), 'r-')
plt.plot(meses, minimos_temperaturas, 'bo')
plt.plot(dias, temperaturas_anuales(dias, *opt_minimos), 'b-')
plt.title('Temperaturas en la Antártida - 2021')
plt.xlabel('Meses')
plt.ylabel('Máximos y Mínimos ($^\circ$C)')
plt.show()

# %% [markdown]
# Una de las características principales de Scipy es su soporte para procesamiento de señales mediante el módulo `scipy.signal`. Veámoslo con un primer ejemplo, en el que muestrearemos una señal $x(t)$ = 50 $cos(t)$, a la que se le ha mezclado ruido en la transmisión:

# %%
tiempo = np.linspace(0, 200, 100)
señal_emitida = 50 * np.cos(tiempo*2*np.pi)
plt.plot(tiempo, señal_emitida)
plt.title("Señal Emitida")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud")
plt.xlim(0, 200)
plt.ylim(-175, 175)
#plt.axis('equal')
plt.show()

# %%
señal_recibida = 50 * np.cos(tiempo) + 50 * np.random.normal(size=100)
from scipy import signal
señal_muestreada = signal.resample(señal_recibida, 25)
plt.plot(tiempo[::4], señal_muestreada, 'ro')
plt.plot(tiempo, señal_recibida)
plt.title("Señal Recibida")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud")
plt.xlim(0, 200)
plt.ylim(-175, 175)
plt.show()

# %% [markdown]
# Procesemos ahora una señal real, correspondiente a un electrocardiograma, en el que la señal recibida requiere ser reconstruida:

# %%
from scipy.misc import electrocardiogram
ecg = electrocardiogram()
plt.plot(ecg)
plt.title("Electrocardiograma")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud (mV)")
plt.show()

# %% [markdown]
# Nótese que la señal así representada no resulta bien caracterizada. Para ello, haremos un proceso de transformación del eje de tiempos y limitaremos la ventana de observación:

# %%
fs = 360
time = np.arange(ecg.size) / fs
plt.plot(time, ecg)
plt.title("Electrocardiograma")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud (mV)")
plt.xlim(9, 10.2)
plt.ylim(-1, 1.5)
plt.show()

# %% [markdown]
# Para este ejemplo, la señal recibida ha sufrido una alteración en el proceso de adquisición, por lo que posteriormente requiere ser recuperada:

# %%
ecg_recibido = ecg + time

# %%
import matplotlib.pyplot as plt
plt.plot(time, ecg_recibido)
plt.title("Electrocardiograma")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud (mV)")
plt.xlim(9, 10.2)
plt.ylim(9, 11)
# Out:
# (9.0, 11.0)

# %%
ecg_detrended = signal.detrend(ecg_recibido)
plt.plot(time, ecg)
plt.plot(time, ecg_detrended)
plt.title("Electrocardiograma")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud (mV)")
plt.xlim(9, 10.2)
plt.ylim(-1, 1.75)
# Out:
# (-1.0, 1.75)

# %% [markdown]
# Veremos ahora la aplicación de `scipy` en procesamiento de imágenes a través del módulo `nd.image`:

# %%
import matplotlib.pyplot as plt
from scipy import misc
imagen = misc.face(gray=True)
print(imagen.shape)
plt.grid(b=None)
#plt.grid(b=bool)
plt.imshow(imagen, cmap=plt.cm.gray)
plt.show()
# Out:
# (768, 1024)

# %% [markdown]
# Procederemos a desplazar la imagen original mediante dos métodos

# %%
from scipy import ndimage
imagen_desplazada = ndimage.shift(imagen, (50, 100))
plt.grid(b=None)
plt.imshow(imagen_desplazada,  cmap=plt.cm.gray)
plt.show()

# %%
imagen_desplazada_b = ndimage.shift(imagen, (50, 100), mode='nearest')
plt.grid(b=None)
plt.imshow(imagen_desplazada_b, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Mediante este módulo podemos también realizar una rotación de la imagen

# %%
imagen_rotada = ndimage.rotate(imagen, 45)
plt.grid(b=None)
plt.imshow(imagen_rotada, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Podremos también llevar a cabo un recorte

# %%
imagen_recortada = imagen[100:-50, 100:-50]
plt.grid(b=None)
plt.imshow(imagen_recortada, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Aplicar un zoom

# %%
imagen_zoom = ndimage.zoom(imagen, 4)
plt.grid(b=None)
plt.imshow(imagen_zoom, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Degradarla con ruido

# %%
imagen = imagen[:1024, -1024:]
imagen_ruidosa = np.copy(imagen).astype(np.float)
imagen_ruidosa += imagen.std() * 0.6 * np.random.standard_normal(imagen.shape)
plt.grid(b=None)
plt.imshow(imagen_ruidosa, cmap=plt.cm.gray)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
imagen_ruidosa - imagen
# Out:
# array([[ 27.10348222,   0.7579571 ,  17.36314847, ...,  47.68920619,
#          12.24941053,   8.39583667],
#        [ -8.29543754,  39.57348064,  -0.30616139, ...,  25.64427125,
#           5.99568665,  60.94209138],
#        [-57.15859097,   7.82186016, -62.34391421, ..., -24.59658796,
#          22.6742017 ,  50.9721798 ],
#        ...,
#        [  4.59736953, -39.71907941, -43.34209539, ...,  19.5360269 ,
#          -6.64121101, -17.05770539],
#        [ 42.99200926,  -0.89259544,  14.40159218, ..., -47.49270816,
#          -9.19508724, -15.58718139],
#        [ 67.79571756,  33.30730803,  16.6103776 , ...,  -7.22144733,
#          28.96762284,  34.09021466]])

# %% [markdown]
# Y luego restaurarla mediante diferentes tipos de filtrado

# %%
imagen_filtrada = ndimage.gaussian_filter(imagen_ruidosa, sigma=3)
filtrado_mediana = ndimage.median_filter(imagen_ruidosa, size=5)
filtrado_wiener = signal.wiener(imagen_ruidosa, (5, 5))
plt.grid(b=None)
plt.imshow(filtrado_mediana, cmap=plt.cm.gray)
#plt.imshow(filtrado_wiener, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Veremos por último la aplicación del módulo `spicy.stats` como soporte a operaciones estadísticas:

# %%
from scipy import stats

# %% [markdown]
# Como ejemplo, construiremos la $fdp$ para una distribución Normal de media $\mu$=4 y varianza $\sigma^2$ = 1

# %%
normal = stats.norm(loc=4.0, scale=1)
variable_aleatoria = np.linspace(0, 8, 100)
fdp = normal.pdf(variable_aleatoria)
plt.plot(variable_aleatoria,fdp)
plt.show()

# %% [markdown]
# y su $FDP$

# %%
FDP = normal.cdf(variable_aleatoria)
plt.plot(variable_aleatoria,FDP)
plt.show()

# %% [markdown]
# Calcularemos para ella los siguientes estadísticos: media, varianza, asimetría y curtosis

# %%
estadisticos = normal.stats(moments="mvsk")
print('Media:', estadisticos[0])
print('Varianza:', estadisticos[1])
print('Asimetría:', estadisticos[2])
print('Curtosis:', estadisticos[3])
# Out:
# Media: 4.0
# Varianza: 1.0
# Asimetría: 0.0
# Curtosis: 0.0

# %% [markdown]
# Calcularemos el valor de $x$ para un valor de la $FDP$ igual a 0.98

# %%
print('x =', normal.ppf(0.98))
# Out:
# x = 6.053748910631823

# %% [markdown]
# Representaremos el histograma para 900 muestras

# %%
variable_aleatoria = normal.rvs(900)
plt.hist(variable_aleatoria, bins=30)
plt.show()

# %% [markdown]
# Inferiremos la media y la varianza para dicho histograma

# %%
location, scale = stats.norm.fit_loc_scale(variable_aleatoria)
print('Estimación de la media: ', location)
print('Estimación de la varianza: ', scale)
# Out:
# Estimación de la media:  3.9892872245428905
# Estimación de la varianza:  1.000485001274274
