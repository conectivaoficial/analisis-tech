# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos ficticios
data = {
    'año': [2018, 2018, 2018, 2019, 2019, 2019, 2020, 2020, 2020],
    'tipo': ['inversión', 'patentes', 'publicaciones', 'inversión', 'patentes', 'publicaciones', 'inversión', 'patentes', 'publicaciones'],
    'valor': [5000, 150, 200, 5500, 160, 210, 6000, 170, 220]
}

df = pd.DataFrame(data)

# %%
# Explorar el Conjunto de Datos

# %%
# Análisis de Tendencias de Inversión en I+D

# %%
# Comparar el Número de Patentes y Publicaciones Científicas
comparación_indicadores = df[df['tipo'].isin(['patentes', 'publicaciones'])].pivot(index='año', columns='tipo', values='valor')

# %%
# Visualización de Resultados
